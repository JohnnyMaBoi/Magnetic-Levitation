# %%
import numpy as np
from matplotlib import pyplot as plt
import scipy.signal
import pandas as pd

# !pip install pint
from pint import UnitRegistry
units = UnitRegistry(system = "mks")
units.default_format = "~P.2e"

# %% [markdown]
# ### Constants and parameters

# %%
mu_0 = 1 * units.vacuum_permeability
N = 100
l = 18 * units.millimeter
R = 34 * units.millimeter / 2
I_original = 1 * units.amp
magnet_dipole = 0.0369 * 100 * units.amp * units.meter ** 2
z_space = np.linspace(0 * units.mm, 100 * units.mm, 1000)
m = (10 + 8.37) * units.gram
g = 1 * units.standard_gravity
res = 1 * units.ohm
Fg = m * g

# %% [markdown]
# ### B field equations
# ![B field equations](images/B_field_equations.png)
# ![F equations](images/F_equation.png)
# ![Lorenz equations](images/Lorenz_equation.png)

# %%
class AccurateModel:
    @classmethod
    def get_B_z_axis(cls, z, I):
        B_z_axis = mu_0 * N * I / 2 * (((l / 2 - z) / (l * np.sqrt(R ** 2 + (l / 2 - z) ** 2))) + ((l / 2 + z) / (l * np.sqrt(R ** 2 + (l / 2 + z) ** 2))))
        return B_z_axis
    @classmethod
    def get_F_z_axis(cls, z, I):
        dz = 10 * units.mm
        zs = np.linspace(z - dz, z + dz, 2)
        B_z_axis = cls.get_B_z_axis(zs, I)
        dBdz = (B_z_axis[1] - B_z_axis[0]) / dz
        F_z_axis = magnet_dipole * dBdz
        return F_z_axis
    @classmethod
    def get_F_z_axis_as_vector(cls, z, I):
        F_z_axis = np.zeros(np.size(z)) * units.newton
        for idx, z_val in enumerate(z):
            F_z_axis[idx] = cls.get_F_z_axis(z_val, I)
        return F_z_axis
    @classmethod
    def get_lorenz_force(cls, z, dzdt):
        Fl = N * -9 * mu_0 ** 2 * magnet_dipole ** 2 * R ** 4 * z ** 2 * dzdt / (4 * res * (R ** 2 + z ** 2) ** 5)
        return Fl
    @classmethod
    def get_gravity_force(cls):
        Fg = m * g
        return Fg

class ShortSolenoidModel:
    @classmethod
    def get_B_z_axis(cls, z, I):
        B_short_solenoid_eq = mu_0 * I * N * R ** 2 / (2 * (R ** 2 + z ** 2) ** (3 / 2)) # From wikipedia: https://en.wikipedia.org/wiki/Solenoid#Short_solenoid_estimate
        return B_short_solenoid_eq
    @classmethod
    def get_F_z_axis(cls, z, I):
        F_short_solenoid_eq = -3 * mu_0 * R ** 2 * N * I * z / (2 * (R ** 2 + z ** 2) ** (5 / 2)) * magnet_dipole # From: https://www.physicsforums.com/insights/how-to-model-a-magnet-falling-through-a-conducting-pipe/
        return F_short_solenoid_eq

B_z_axis = AccurateModel.get_B_z_axis(z_space, I_original)
F_z_axis = AccurateModel.get_F_z_axis_as_vector(z_space, I_original)
B_short_solenoid_eq = ShortSolenoidModel.get_B_z_axis(z_space, I_original)
F_short_solenoid_eq = ShortSolenoidModel.get_F_z_axis(z_space, I_original)

plt.plot(z_space.to(units.cm), B_z_axis.to(units.millitesla), label = "Numeric diff. of full equation")
plt.plot(z_space.to(units.cm), B_short_solenoid_eq.to(units.millitesla), linestyle = "dotted", label = "Explicit equation from Physics Forums")
plt.xlabel("Distance (cm)")
plt.ylabel("Magnetic Field Strength (mT)")
plt.legend(loc = "lower right")

# %% [markdown]
# ### Linearizing the force

# %%
def linreg(x, y):
    A = np.vstack([x.magnitude, np.ones(len(x))]).T
    slope, intercept = np.linalg.lstsq(A, y.magnitude, rcond=None)[0]
    slope = slope * y.units / x.units
    intercept = intercept * y.units
    return slope, intercept

def linreg_points(x, y, start_lin_reg, end_lin_reg):
    lin_reg_range = (start_lin_reg <= x) & (x <= end_lin_reg)
    new_x = x[lin_reg_range]
    new_y = y[lin_reg_range]
    slope, intercept = linreg(new_x, new_y)
    return slope, intercept, new_x, new_x * slope + intercept

start_lin_reg = 15 * units.mm
end_lin_reg = 30 * units.mm
lin_reg_range = (start_lin_reg <= z_space) & (z_space <= end_lin_reg)
dFdz_at_original_I, F_intercept_at_original_I, z_lin_reg, Fm_lin_reg = linreg_points(z_space, F_z_axis, start_lin_reg, end_lin_reg)

plt.plot(z_space.to(units.mm), F_z_axis.to(units.newton), label = "Numeric diff. of full equation")
plt.plot(z_space.to(units.mm), F_short_solenoid_eq.to(units.newton), linestyle = "dotted", label = "Explicit equation from Physics Forums")
plt.plot(z_lin_reg.to(units.mm), Fm_lin_reg.to(units.newton), linestyle = "dashed", color = "black", label = "Linearization")
plt.xlabel("Distance (mm)")
plt.ylabel("Fm (N)")
plt.axvline(x = start_lin_reg.to(units.mm).magnitude, color = "grey", linestyle = "dashed")
plt.axvline(x = end_lin_reg.to(units.mm).magnitude, color = "grey", linestyle = "dashed")
plt.legend(loc = "lower right")

# %% [markdown]
# ### Calculating Z0 and I0

# %%
z0 = 20 * units.mm

Fm_at_z0_given_original_I = AccurateModel.get_F_z_axis(z0, I_original)
print(f"Force at z = z0 = {z0.to(units.mm)} given an original current of {I_original.to(units.amp)} is {Fm_at_z0_given_original_I.to(units.newton)}")
I0 = Fg / -Fm_at_z0_given_original_I * I_original
print(f"Current must be set to {I0.to(units.amp)} to achieve steady-state with a gravitational force of {Fg.to(units.N)}")

F_z_axis_at_I0 = AccurateModel.get_F_z_axis_as_vector(z_space, I0)
dFdz_at_I0, F_intercept_at_I0, z_lin_reg, Fm_lin_reg = linreg_points(z_space, F_z_axis_at_I0, start_lin_reg, end_lin_reg)

unit_dzdt = 1 * units.mm / units.s
b = -AccurateModel.get_lorenz_force(z0, unit_dzdt) / unit_dzdt
a = dFdz_at_I0
Fm0 = Fm_at_z0_given_original_I / I_original
print(f"dFdz = {a.to(units.newton / units.mm)}")
print(f"dFdv = {b.to(units.newton / (units.mm / units.second))}")
# Out:
# Force at z = z0 = 2.00×10¹ mm given an original current of 1.00×10⁰ A is -7.05e-01 N
# Current must be set to 2.56×10⁻¹ A to achieve steady-state with a gravitational force of 1.80×10⁻¹ N
# dFdz = 9.59×10⁻³ N/mm
# dFdv = 1.04×10⁻⁶ N·s/mm

# %%
current_vs_pwm_data = pd.read_csv("../solenoid_current_data_analysis\current_step1.csv", sep = "\t")
current_vs_pwm_data.rename(columns = {"Solenoid value (0-255)": "solenoid_write", "Current (A)": "current"}, inplace = True)
current_vs_pwm_data.dropna(inplace = True)
# print(current_vs_pwm_data)
current_pwm_slope, current_pwm_intercept = linreg(np.array(current_vs_pwm_data["solenoid_write"]) * units.dimensionless, np.array(current_vs_pwm_data["current"]) * units.amp)
print(f"slope = {current_pwm_slope}, intercept = {current_pwm_intercept}")

plt.scatter(np.array(current_vs_pwm_data["solenoid_write"]) * units.dimensionless, np.array(current_vs_pwm_data["current"]) * units.amp)
plt.plot(np.array(current_vs_pwm_data["solenoid_write"]) * units.dimensionless, np.array(current_vs_pwm_data["solenoid_write"]) * current_pwm_slope + current_pwm_intercept, color = "black", linestyle = "dashed")
plt.xlabel("PWM to Solenoid (0-255)")
plt.ylabel("Current through solenoid (A)")
# Out:
# slope = 2.50×10⁻³ A, intercept = -3.31e-01 A
# c:\Users\ieykamp\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\ma\core.py:2820: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\ieykamp\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook.py:1345: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# Text(0, 0.5, 'Current through solenoid (A)')

# %%
distance_vs_field_strength_data = pd.read_csv("distance_vs_field_strength.csv")
print(distance_vs_field_strength_data.columns)
distance_field_strength_slope, distance_field_strength_intercept, linear_distance, linear_field_strength = linreg_points(np.array(distance_vs_field_strength_data["distance_cm"]) * units.centimeter, np.array(distance_vs_field_strength_data["field_strength_mT"]) * units.millitesla, 0.2 * units.cm, 0.9 * units.cm)
print(f"slope = {distance_field_strength_slope}, intercept = {distance_field_strength_intercept}")

plt.scatter(np.array(distance_vs_field_strength_data["distance_cm"]) * units.centimeter, np.array(distance_vs_field_strength_data["field_strength_mT"]) * units.millitesla)
# plt.plot(np.array(distance_vs_field_strength_data["distance_cm"]) * units.centimeter, np.array(distance_vs_field_strength_data["distance_cm"]) * units.centimeter * distance_field_strength_slope + distance_field_strength_intercept, color = "black", linestyle = "dashed")
plt.plot(linear_distance, linear_field_strength, color = "black", linestyle = "dashed")
plt.plot(np.array(distance_vs_field_strength_data["distance_cm"]) * units.centimeter, np.array(30 / (distance_vs_field_strength_data["distance_cm"]) ** 2) * units.millitesla)
plt.ylim(0, 350)
plt.xlabel("Distance from solenoid (cm)")
plt.ylabel("Field strength (mT)")
plt.title("Data taken with Nature's valley boxes")

class Hardware():
    def solenoid_pwm_to_current(self, solenoid_pwm):
        return solenoid_pwm * current_pwm_slope + current_pwm_intercept
    def current_to_solenoid_pwm(self, current):
        return (current - current_pwm_intercept) / current_pwm_slope
    def field_strength_to_distance(self, field_strength):
        return np.interp(field_strength, np.array(distance_vs_field_strength_data.sort_values("field_strength_mT")["field_strength_mT"]) * units.millitesla, np.array(distance_vs_field_strength_data.sort_values("field_strength_mT")["distance_cm"]) * units.centimeters)
    def distance_to_field_strength(self, distance):
        return np.interp(distance, np.array(distance_vs_field_strength_data.sort_values("distance_cm")["distance_cm"]) * units.centimeters, np.array(distance_vs_field_strength_data.sort_values("distance_cm")["field_strength_mT"]) * units.millitesla)

hardware = Hardware()
print(hardware.solenoid_pwm_to_current(180))
print(hardware.current_to_solenoid_pwm(0.26 * units.amp))
print(hardware.distance_to_field_strength(1.1 * units.centimeter))
print(hardware.field_strength_to_distance(300 * units.millitesla))
# Out:
# Index(['distance_cm', 'field_strength_mT'], dtype='object')
# slope = -4.01e+02 mT/cm, intercept = 3.55×10² mT
# 1.20×10⁻¹ A
# 2.36×10²
# 3.35×10¹ mT
# 2.26×10⁻¹ cm
# c:\Users\ieykamp\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\ma\core.py:2820: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\ieykamp\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook.py:1345: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %% [markdown]
# ### Controller
#
# $m \ddot{z} + b \dot{z} - a (z - z_0) = F_{m0} (I - I_0)$
# Transfer function $G(s) = \frac{(z - z_0)(s)}{(I - I_0)(s)} = \frac{F_{m0}}{m s^2 + b s - a}$
# Poles at $\frac{-b \pm \sqrt{(b^2 + 4 m a)}}{2m}$

# %%
print(f"b = {b.to(units.newton / (units.m / units.s))}")
print(f"m = {m.to(units.kg)}")
print(f"a = {a.to(units.newton / units.m)}")
print(f"Fm0 = {Fm0.to(units.newton / units.amp)}")
poles = [((-b + np.sqrt(b ** 2 + 4 * m * a)) / (2 * m)).to(1 / units.s), ((-b - np.sqrt(b ** 2 + 4 * m * a)) / (2 * m)).to(1 / units.s)]
print(poles)

def between(minimum, maximum, val):
    if val < minimum:
        return minimum
    if val > maximum:
        return maximum
    return val

controller_time_delay_p = 5 * units.millisecond
controller_time_delay_d = 5 * units.millisecond
def controller(Δz, dΔzdt):
    ΔI = between(-0.2 * units.amp, 0.2 * units.amp, 160 / 1000 * units.amp / units.mm * Δz + 6 / 1000 * units.amp / (units.mm / units.s) * dΔzdt)
    return ΔI
# Out:
# b = 1.04×10⁻³ N·s/m
# m = 1.84×10⁻² kg
# a = 9.59×10⁰ N/m
# Fm0 = -7.05e-01 N/A
# [<Quantity(22.8235202, '1 / second')>, <Quantity(-22.880184, '1 / second')>]

# %% [markdown]
# ### Difference Equation (try # 2)

# %%
ts = np.linspace(0 * units.second, 1 * units.second, 300)
dt = np.mean(np.diff(ts))
Δz_t = np.zeros(np.size(ts)) * units.mm
ΔI_t = np.zeros(np.size(ts)) * units.amp
dzdt0 = 0 * units.mm / units.s
for n, t in enumerate(ts, start = 0):
    if n == 0:
        Δz_t[n] = -1 * units.mm
    elif n == 1:
        Δz_t[n] = Δz_t[0] + dzdt0 * dt
    elif abs(Δz_t[n - 1]) > 100 * units.mm:
        break
    else:
        controller_timesteps_delay_p = int(controller_time_delay_p / dt)
        controller_timesteps_delay_d = int(controller_time_delay_d / dt)
        ΔI_t[n] = controller(Δz_t[n - 1 - controller_timesteps_delay_p], (Δz_t[n - 1 - controller_timesteps_delay_d] - Δz_t[n - 2 - controller_timesteps_delay_d]) / dt)
        Δz_t[n] = (ΔI_t[n] * Fm0 + m / dt ** 2 * (2 * Δz_t[n - 1] - Δz_t[n - 2]) + b / dt * (Δz_t[n - 1])) / (m / dt ** 2 + b / dt - a)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax2.plot(ts, ΔI_t.to(units.amp), color = "orange", label = "I_t")
ax1.plot(ts, Δz_t.to(units.mm), color = "blue", label = "z_t")
ax1.set_xlabel("Time (s)")
ax2.set_ylabel("Current from I0 (A)")
ax1.set_ylabel("Position from z0 (mm)")
fig.legend(loc = "lower right")

# %% [markdown]
# ### Physical model
# Warning: overwriting the variables `z_t` and `I_t`

# %%
ts = np.linspace(0 * units.second, 1 * units.second, 1000)
dt = np.mean(np.diff(ts))
z_t =    np.zeros(np.size(ts)) * units.mm
dzdt =   np.zeros(np.size(ts)) * units.mm / units.s
d2zdt2 = np.zeros(np.size(ts)) * units.mm / units.s ** 2
I_t = np.zeros(np.size(ts)) * units.amp
dzdt0 = 0 * units.mm / units.s
for n, t in enumerate(ts, start = 0):
    if n == 0:
        z_t[n] = z0 - 3 * units.mm
        I_t[n] = I0
    elif n == 1:
        z_t[n] = z_t[0] + dzdt0 * dt
        I_t[n] = I0
    elif abs(z_t[n - 1]) > 100 * units.mm:
        break
    else:
        I_t[n] = I0 + controller(z_t[n - 1] - z0, (z_t[n - 1] - z_t[n - 2]) / dt)
        # force equations
        Fm = AccurateModel.get_F_z_axis(z_t[n - 1], I_t[n - 1])
        Fl = AccurateModel.get_lorenz_force(z_t[n - 1], dzdt[n - 1])
        Fg = AccurateModel.get_gravity_force()
        Fnet = Fm + Fl + Fg
        d2zdt2[n] = Fnet / m
        dzdt[n] = dzdt[n - 1] + d2zdt2[n] * dt
        z_t[n] = z_t[n - 1] + dzdt[n] * dt

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(ts, z_t.to(units.mm), color = "blue", label = "z_t")
ax2.plot(ts, I_t.to(units.amp), color = "orange", label = "I_t")
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Position (mm)")
ax2.set_ylabel("Current (A)")
ax1.legend(loc = "upper right")
ax2.legend(loc = "lower right")
